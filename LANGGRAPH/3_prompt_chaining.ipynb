# %%
from langgraph.graph import StateGraph,START ,END
from typing import TypedDict
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI()

# %%
class BlogState(TypedDict):
    title:str
    outline:str
    content:str

# %%
def create_outline(state:BlogState) -> BlogState:
    title = state['title']
    prompt = f'Create a catchy blog title for the topic: {title}'
    outline = model.invoke(prompt).content
    state['outline']=outline
    return state

# %%
def create_blog(state:BlogState) -> BlogState:
    title=state['title']
    outline=state['outline']
    prompt = f"Write a detailed blog on the title: {title} and outline: {outline}"
    content = model.invoke(prompt).content
    state['content']=content
    return state

# %%
graph = StateGraph(BlogState)
graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)
graph.add_edge(START,'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)
workflow = graph.compile()

# %%
inital_state = BlogState(title="Artificial Intelligence",outline="",content="")
final_state = workflow.invoke(inital_state)
print(final_state['content'])
# Out:
# Artificial Intelligence (AI) has become one of the most powerful and transformative technologies of our time. It has the potential to revolutionize every aspect of our lives, from healthcare and transportation to finance and entertainment. The possibilities are endless, and the impact of AI on society is already starting to be felt.
#
# One of the key benefits of AI is its ability to automate tasks that were previously thought to be the exclusive domain of humans. This includes anything from driving a car to diagnosing complex medical conditions. By leveraging AI, businesses and governments are able to increase efficiency, reduce costs, and deliver new and improved services to their customers and citizens.
#
# AI also has the power to unlock new insights and opportunities by analyzing vast amounts of data in ways that humans simply can’t. This has already led to breakthroughs in areas such as drug discovery, weather forecasting, and customer behavior analysis. By harnessing the power of AI, organizations can gain a competitive advantage and drive innovation in ways that were previously unimaginable.
#
# Furthermore, AI has the potential to transform education and training by providing personalized learning experiences that cater to the needs of each individual student. This can help to close the achievement gap and ensure that everyone has access to high-quality education, regardless of their background or circumstances. AI can also help to democratize access to information by providing instant translation services and making knowledge more accessible to all.
#
# In the medical field, AI is already being used to diagnose diseases, predict patient outcomes, and personalize treatment plans. By analyzing patient data and medical images, AI can help doctors make more accurate diagnoses and provide better care to their patients. This has the potential to save lives and improve the quality of healthcare for everyone.
#
# However, AI also raises important ethical and societal questions that must be addressed. For example, there are concerns about the potential loss of jobs as AI automates tasks that were previously done by humans. There are also concerns about bias and discrimination in AI algorithms, which can perpetuate existing inequalities and stereotypes. It is important for developers and policymakers to work together to ensure that AI is used in ways that are fair, transparent, and accountable.
#
# In conclusion, the power of artificial intelligence is undeniable. By unlocking the potential of AI, we have the opportunity to revolutionize our world and create a future that is brighter and more inclusive for all. It is up to us to shape the future of AI in a way that benefits everyone and ensures that this powerful technology is used for the greater good.

# %%
print(final_state)
# Out:
# {'title': 'Artificial Intelligence', 'outline': '"Unlocking the Future: The Power of Artificial Intelligence"', 'content': 'Artificial Intelligence (AI) has become one of the most powerful and transformative technologies of our time. It has the potential to revolutionize every aspect of our lives, from healthcare and transportation to finance and entertainment. The possibilities are endless, and the impact of AI on society is already starting to be felt.\n\nOne of the key benefits of AI is its ability to automate tasks that were previously thought to be the exclusive domain of humans. This includes anything from driving a car to diagnosing complex medical conditions. By leveraging AI, businesses and governments are able to increase efficiency, reduce costs, and deliver new and improved services to their customers and citizens.\n\nAI also has the power to unlock new insights and opportunities by analyzing vast amounts of data in ways that humans simply can’t. This has already led to breakthroughs in areas such as drug discovery, weather forecasting, and customer behavior analysis. By harnessing the power of AI, organizations can gain a competitive advantage and drive innovation in ways that were previously unimaginable.\n\nFurthermore, AI has the potential to transform education and training by providing personalized learning experiences that cater to the needs of each individual student. This can help to close the achievement gap and ensure that everyone has access to high-quality education, regardless of their background or circumstances. AI can also help to democratize access to information by providing instant translation services and making knowledge more accessible to all.\n\nIn the medical field, AI is already being used to diagnose diseases, predict patient outcomes, and personalize treatment plans. By analyzing patient data and medical images, AI can help doctors make more accurate diagnoses and provide better care to their patients. This has the potential to save lives and improve the quality of healthcare for everyone.\n\nHowever, AI also raises important ethical and societal questions that must be addressed. For example, there are concerns about the potential loss of jobs as AI automates tasks that were previously done by humans. There are also concerns about bias and discrimination in AI algorithms, which can perpetuate existing inequalities and stereotypes. It is important for developers and policymakers to work together to ensure that AI is used in ways that are fair, transparent, and accountable.\n\nIn conclusion, the power of artificial intelligence is undeniable. By unlocking the potential of AI, we have the opportunity to revolutionize our world and create a future that is brighter and more inclusive for all. It is up to us to shape the future of AI in a way that benefits everyone and ensures that this powerful technology is used for the greater good.'}

# %%
print(final_state['outline'])
# Out:
# "Unlocking the Future: The Power of Artificial Intelligence"
